# %% [markdown]
# <a href="https://colab.research.google.com/github/michaelwnau/ai_academy_notebooks/blob/main/lecture_notes_2023_08_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
2023-08-07

lecture.
what model of the world should be used?
knowledge based agent - question asking
choose minimal representation that covers the questions but is also most efficient (compute etc.)
frame representation vs belief network vs scripts
frame representation

on google vs bing, search llm

knowledge engineering process

1. identify the task
	- what are the questions to be answered
	- what facts to we need for each one?
	-  PEAS specification

2. Assemble the knowledge
	- knowledge acquisition - bottleneck.
	- determine how the domain works.
	- engage in knowledge elicitation.



ex. Pay my taxes
PEAS

P - performance - keeping the state of the golf course, 'health of the greens'
E - environment - course, weather,
A - actuator - irrigation/sprinkler
S - sensors - rain sensor, temp, moisture, cameras, satellite etc.
		https://www.precisionfarmingdealer.com/articles/5346-john-deere-bets-on-satellite-technology-for-precision-ag
3. select the vocabulary / reprsentationb
	- what fxs, prediicates, etc
	- define the domain ontology -
	- crucial for efficiency

4.  encode general knowledge
	- write down all basic axioms
	- implement a basic KB

5. encode a specific problem
	- actually realize a problem in the representation
	- encode problem-specific KB and complex knowledge
	- consider
6. pose queries
	- extract info from the KB to get answers

7. debug
	- check the KB for inconsistencies
	- reevaluate basic representation decisions

###################################################

1. Identify the Task
Questions to be Answered:

How can we maintain optimal health for the greens?
What areas of the course require irrigation?
How can we predict and preemptively respond to adverse weather conditions?
When and where should maintenance activities (like mowing or aeration) take place?
Facts Needed:

Current moisture levels across the course.
Weather forecasts.
Last maintenance activity per course area.
Previous and forecasted foot traffic on greens.
PEAS Specification:

P (Performance Measure): Health and quality of greens, playability of the course, player satisfaction.
E (Environment): Golf course, including greens, fairways, bunkers, weather conditions, season.
A (Actuators): Irrigation systems, maintenance machinery (mowers, aerators), drainage systems.
S (Sensors): Rain sensors, soil moisture sensors, temperature sensors, cameras (for foot traffic monitoring), satellites (for comprehensive aerial data).
2. Assemble the Knowledge
Knowledge Acquisition: Engage with golf course superintendents, groundskeepers, and other experts to understand the nuances of managing golf courses.
Knowledge Elicitation: Conduct interviews, surveys, and observations to understand the tacit knowledge that experienced staff apply to manage courses.
3. Select the Vocabulary / Representation
Functions/Predicates:
needsIrrigation(area), requiresMaintenance(area, type), predictWeatherImpact(date), trafficFlow(date, area).
Domain Ontology:
Entities: Green, fairway, bunker, tee box, clubhouse, machinery.
Relationships: isAdjacentTo, hasMoistureLevel, hasTrafficLevel, requiresMachinery.
4. Encode General Knowledge
Basic Axioms:
If a green's moisture level is below a certain threshold, then it requires irrigation.
Regular maintenance (like mowing) needs to occur at specified intervals.
Drainage systems activate upon detecting a certain amount of rainfall.
Implement a Basic KB: Create a knowledge base (KB) where the rules, entities, and relationships are defined.
5. Encode a Specific Problem
Problem Representation: How can we predict the best times for maintenance activities based on upcoming weather patterns, current soil moisture, and expected player traffic?
Problem-specific KB: Integrate data from weather forecasting APIs, satellite imagery, and past course activity to develop a predictive model.
6. Pose Queries
Examples:
Which areas of the course need irrigation today?
What is the predicted foot traffic for green #5 tomorrow?
Is there a likelihood of course flooding next week?
7. Debug
Check KB for Inconsistencies: Ensure the knowledge rules do not conflict.
Reevaluate Basic Representation Decisions: As the system is tested and iterated upon, some foundational choices may need revisiting.
Further Consideration
With the advent of AI and ML, much of this process could be automated or made predictive. For instance, predictive analytics could foresee the need for course maintenance or irrigation before it becomes apparent to humans. Similarly, machine learning can optimize irrigation patterns based on historical data, current soil conditions, and weather predictions.
'''
