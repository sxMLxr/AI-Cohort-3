# %% [markdown]
# <a href="https://colab.research.google.com/github/michaelwnau/ai_academy_notebooks/blob/main/simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Demo with hard-coded synethetic data

import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Create some dummy data
np.random.seed(0)
x = np.random.rand(100, 1)
y = 2 + 3 * x + np.random.rand(100, 1)

# Fit a linear regression model to the data
model = LinearRegression()
model.fit(x, y)

# Get the line of best fit
x_fit = np.linspace(0, 1, 100)[:, np.newaxis]
y_fit = model.predict(x_fit)

# Plot the data and the line of best fit
plt.scatter(x, y)
plt.plot(x_fit, y_fit, 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression Plot')
plt.show()

# %%
# This version will take data from a CSV file that contains X and Y column values

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Import your CSV data
data = pd.read_csv('your_file_path.csv')
x = data[['x']].values
y = data[['y']].values

# Fit a linear regression model to the data
model = LinearRegression()
model.fit(x, y)

# Get the line of best fit
x_fit = np.linspace(min(x), max(x), 100)
y_fit = model.predict(x_fit)

# Plot the data and the line of best fit
plt.scatter(x, y)
plt.plot(x_fit, y_fit, 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression Plot')
plt.show()
